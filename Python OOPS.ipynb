# %% [markdown]
# # 1. What is Object-Oriented Programming (OOP)?
#   -- Object oriented programming OOPS is doing programming using classes and objects using different functions.

# %% [markdown]
# # 2.What is a class in OOP?
#   -- Class is a blueprint of an object in OOPS.

# %% [markdown]
# # 3. What is an object in OOP?
#   --Object is an instance of an class

# %% [markdown]
# # 4.What is the difference between abstraction and encapsulation?
#   -- Abstraction is the process of hiding complex implementation details and showing only the essential features of an object.
#      Encapsulation is the bundling of data (attributes) and methods (functions) that operate on that data into a single unit (i.e., a class), and restricting access to some of the object’s components.

# %% [markdown]
# # 5. What are dunder methods in Python?
#   -- Dunder methods are Double underscore methods or magic methods used in python. for eg. __init__ ,__add__

# %% [markdown]
# # 6. Explain the concept of inheritance in OOPS.
#   -- Inheritance is the process of using the child class under the parent class and using its methods and functions.
#     for eg.
#     # Parent class
# class Animal:
#     def speak(self):
#         print("The animal makes a sound")
#
# # Child class
# class Dog(Animal):
#     def bark(self):
#         print("The dog barks")
#
# # Using inheritance
# d = Dog()
# d.speak()  # Inherited from Animal
# d.bark()   # Defined in Dog

# %% [markdown]
#  # 7. What is polymorphism in OOP?
#    -- Polymorphism means "many forms". It allows objects of different classes to be treated as objects of a common superclass, particularly when they share the same interface (i.e., method names), but may behave differently.

# %% [markdown]
# # 8. How is encapsulation achieved in Python?
#   -- Encapsulation in Python is achieved by restricting access to the attributes and methods of an object and exposing a controlled interface to interact with it. bu using Public, Private and protected methods.

# %% [markdown]
# # 9. What is a constructor in Python?
#   -- Constructor method is use to initialize the methods. (__init__ )
#   is the constructor

# %% [markdown]
# # 10.  What are class and static methods in Python?
#   -- class methods and static methods are two special kinds of methods you can define inside a class, in addition to instance methods.
#    @staticmethod , @classmethod

# %% [markdown]
# # 11. What is method overloading in Python?
#   --Method overloading is a concept where multiple methods have the same name but different parameters. Python doesn't support method overloading.

# %% [markdown]
# # 12. What is method overriding in OOP?
#   -- Method overriding is a concept where a child class uses the same method which is there in parent class with some different functionality.

# %% [markdown]
# # 13. What is a property decorator in Python?
#   -- The @property decorator in Python is a way to use methods like attributes

# %% [markdown]
# # 14. Why is polymorphism important in OOP?
#   -- Polymorphism allows one interface to represent different underlying forms (data types), making your code more flexible, scalable, and easier to maintain.

# %% [markdown]
# # 15. What is an abstract class in Python?
#   -- An abstract class is a class that cannot be instantiated on its own and is meant to be a base class for other classes. It usually contains one or more abstract methods — methods declared but without implementation — that must be overridden by any subclass.

# %% [markdown]
# # 16. What are the advantages of OOP?
#   -- Advantages of OOPS are reusablity, scalablity, encapsulation, polymorphism, abstraction, etc.

# %% [markdown]
# # 17. What is the difference between a class variable and an instance variable?
#   -- Class variable Belongs to the class itself, shared by all instances of that class.
#      Instance variable Belongs to a specific instance (object) of the class.

# %% [markdown]
# # 18. What is multiple inheritance in Python?
#   -- In multiple inheritance a child class can inherit from more than 1 parent class.

# %% [markdown]
# # 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#   -- ___str___ used for readable output. Called by the str() function and print() statements.
#      ___repr___ is used for debugging. Called by the repr() function or when you type an object directly in the console.

# %% [markdown]
# # 20.  What is the significance of the ‘super()’ function in Python?
#   --The super() function in Python is used to call methods from a parent (super) class inside a subclass. It’s most commonly used in inheritance, especially when overriding methods like __init__() or __str__().

# %% [markdown]
# # 21. What is the significance of the __del__ method in Python?
#   --

# %% [markdown]
# # 22. What is the difference between @staticmethod and @classmethod in Python?
#   --@staticmethod A method that belongs to the class but doesn’t access class or instance data.
#
#     @classmethod A method that receives the class itself as the first argument (cls).

# %% [markdown]
# # 23. How does polymorphism work in Python with inheritance?
#    -- Polymorphism with inheritance allows objects of different subclasses to be treated as instances of the parent class, while still behaving according to their specific subclass implementation.

# %% [markdown]
# # 24. What is method chaining in Python OOP?
#   --

# %% [markdown]
# # 25. What is the purpose of the __call__ method in Python?
#   -- The __call__ method in Python allows an object of a class to be called like a function. When you define __call__ in a class, you can use instances of that class as callable objects.

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
      print("The animal makes a sound")

class Dog(Animal):
    def speak(self):
      print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math


class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


circle = Circle(8)
rectangle = Rectangle(4, 9)

print(f"Area of Circle: {circle.area():.2f}")
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 201.06
# Area of Rectangle: 36

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self,type):
        self.type = type

class Car(Vehicle):
    def __init__(self,color):
        self.color = color
        super().__init__("Car")

class ElectricCar(Car):
    def __init__(self,battery):
        self.battery = battery
        super().__init__("ElectricCar")

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
      print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
      print("Sparrow is flying")

class Penguin(Bird):
    def fly(self):
      print("Penguin cannot fly")

bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

bird.fly()
sparrow.fly()
penguin.fly()
# Out:
# Bird is flying
# Sparrow is flying
# Penguin cannot fly

# %%
# 5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self,balance):
        self.__balance = balance

    def deposit(self,amount):
        self.__balance += amount

    def withdraw(self,amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        return self.__balance

account = BankAccount(49000)
account.deposit(1000)
account.withdraw(290)
print(account.check_balance())
# Out:
# 49710

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

class Instrument:
    def play(self):
      print("Instrument is playing")

class Guitar(instrument):
    def play(self):
      print("Guitar is playing")

class Piano(instrument):
    def play(self):
      print("Piano is playing")

guitar = Guitar()
piano = Piano()

guitar.play()
piano.play()

instrument = Instrument()

instrument.play()
# Out:
# Guitar is playing
# Piano is playing
# Instrument is playing

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

person1 = Person()
person2 = Person()
print(Person.get_count())
# Out:
# 2

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

fraction = Fraction(numerator=3, denominator=4)
print(fraction)
# Out:
# 3/4

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self,other):
        return Vector(self.x + other.x, self.y + other.y)

vector = Vector(1,4)
vector2 = Vector(2,3)
print(vector + vector2)

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
 # {name} and I am {age} years old."

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

g = Person("  Saransh",25)
g.greet()
# Out:
# Hello, my name is   Saransh and I am 25 years old.

# %%
# 12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

class Student:
    def __init__(self,name,grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades)/len(self.grades)

stud = Student("Saransh",[10,20,30,40])
stud.average_grade()
# Out:
# 25.0

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

class rectangle:
    def __init__(self,length,width):
      self.length = length
      self.width = width

    def set_dimensions(self,length,width):
      self.length = length
      self.width = width

    def area(self):
      return self.length * self.width

rect = rectangle(4,5)
rect.area()
# Out:
# 20

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self,name,hours_worked,hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
class Manager(Employee):
    def __init__(self,name,hours_worked,hourly_rate,bonus):
        super().__init__(name,hours_worked,hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate + self.bonus

sal = Manager("Saransh",40,50,10000)
sal.calculate_salary()
# Out:
# 12000

# %%
# 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

class product:
    def __init__(self,name,price,quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity\

prod = product("cycle",1000,20)
prod.total_price()
# Out:
# 20000

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

class Animal:
    def sound(self):
      print("Animal is making a sound")

class Cow(Animal):
    def sound(self):
      print("Cow is making a sound")

class Sheep(Animal):
    def sound(self):
      print("Sheep is making a sound")

animal = Animal()
cow = Cow()
sheep = Sheep()

animal.sound()
cow.sound()
sheep.sound()
# Out:
# Animal is making a sound
# Cow is making a sound
# Sheep is making a sound

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

class Book:
    def __init__(self,title,author,year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

b = Book("Criminal jsutice","Saransh",2025)
b.get_book_info()
# Out:
# 'Title: Criminal jsutice\nAuthor: Saransh\nYear Published: 2023'

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

class House:
    def __init__(self,address,price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self,address,price,number_of_rooms):
        super().__init__(address,price)
        self.number_of_rooms = number_of_rooms
